# %% [markdown]
# # ***Projet fin de semestre ***

# %% [markdown]
# # Importation des modules

# %%
import pandas as pd

# %% [markdown]
# # Importation de bases de données

# %%
from google.colab import files 
import io
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import files
#       2 import io
#       3 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %%
df = pd.read_excel(io.BytesIO(uploaded['WaterQuality.xlsx'])) 
df
# Out:
#     Year POINTS    pH   T°C    DCO  DBO5  O2 DISSOUS  CONDUCTIVITE  MES  \
# 0   2016    P 1  8.05  20.9   9.88     5        5.90          1110    4
# 1   2016    P 2  7.27  20.7  15.30    10        5.70          1160    8
# 2   2016    P 3  7.67  20.8   5.20     4        6.70          1280   22
# 3   2016    P 4  7.17  20.9   3.76     3        6.80          1150   17
# 4   2016    P 5  7.88  20.7   4.00     2        6.90           980    2
# 5   2016    P 6  7.43  20.3  18.74     7        3.20          2800    3
# 6   2016    P 7  7.86  20.4   8.54     8        7.56          1150    4
# 7   2016    P 8  7.47  18.8  32.00    29        2.08          3100  130
# 8   2016    P 9  7.63  19.8   1.05     0        4.84          1170    0
# 9   2017    P 1  7.15  20.3  42.90    18        4.06          1050   13
# 10  2017    P 2  7.42  20.2  35.20    20        4.30          1090   13
# 11  2017    P 3  6.93  20.5  27.70    15        5.08          1070    9
# ...

# %% [markdown]
# # Creation des class nessacaire pour le calcule

# %% [markdown]
# **class WAWQI**

# %%
class WAWQI :

  def __init__(self, Si, wi):
   
    self.si = Si
    self.wi = wi
    self.Calcul_WAWQI()

  def Calcul_Qi(self, b):

    if b == 0 :
      self.Qi = (df.loc[b, "pH"] - 8.5) / (6.5 - 8.5)

    else:
      if b <= 11 :
        self.Qi = (df.loc[self.IPL , df.keys()[b +2]]*100)/ self.si[b]
    
    return self.Qi
  
  def Calcul_wi(self, a):

    return self.wi[a]/sum(self.wi)
  
  def Calcul_WAWQI(self):
        self.IPL = 0
        self.total_SI = []

  #boucle sur les lignes

        for y in range(0, 18):
          SI = 0
          #boucle sur les colones
          for x in range(0, 12):
              chaymae = self.Calcul_wi(x) * self.Calcul_Qi(x)
              SI += chaymae
          self.total_SI.append(SI)
          self.IPL += 1
        df['valeurs de WAWQI']=self.total_SI
        print(df)
Si= [6.5 - 8.5, 30, 90, 3.00, 5.00, 1000.00, 20.00, 5.00, 0.5 ,50, 0.5, 5]
wi = [4, 1, 3, 4, 5, 4, 2, 2, 5, 5, 5, 5]
WAWQI(Si,wi)
# Out:
#     Year POINTS    pH   T°C    DCO  DBO5  O2 DISSOUS  CONDUCTIVITE  MES  \
# 0   2016    P 1  8.05  20.9   9.88     5        5.90          1110    4
# 1   2016    P 2  7.27  20.7  15.30    10        5.70          1160    8
# 2   2016    P 3  7.67  20.8   5.20     4        6.70          1280   22
# 3   2016    P 4  7.17  20.9   3.76     3        6.80          1150   17
# 4   2016    P 5  7.88  20.7   4.00     2        6.90           980    2
# 5   2016    P 6  7.43  20.3  18.74     7        3.20          2800    3
# 6   2016    P 7  7.86  20.4   8.54     8        7.56          1150    4
# 7   2016    P 8  7.47  18.8  32.00    29        2.08          3100  130
# 8   2016    P 9  7.63  19.8   1.05     0        4.84          1170    0
# 9   2017    P 1  7.15  20.3  42.90    18        4.06          1050   13
# 10  2017    P 2  7.42  20.2  35.20    20        4.30          1090   13
# 11  2017    P 3  6.93  20.5  27.70    15        5.08          1070    9
# ...
